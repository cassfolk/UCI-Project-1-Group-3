# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt1
import seaborn as sns

# %%
# Begin -start  ABrar 10/26/2020 - 
# Load data from csv to the data frame 

movie_temp_df = pd.read_csv("Resources/movie_list.csv")
movie_temp_df.head()
# Out:
#    Unnamed: 0     tconst release_date     budget    revenue  genres  \
# 0           0  tt0810819   2015-01-01   15000000   64191523   Drama
# 1           1  tt0884732   2015-01-16   23000000   79799880  Comedy
# 2           2  tt2250912   2017-07-05  175000000  880166924  Action
# 3           3  tt1014763   2015-03-15   50000000    3324330   Crime
# 4           4  tt1083452   2016-02-26   23000000   46152411  Comedy
#
#   original_language origin_country production_countries name  \
# 0          Français             DE                   Germany
# 1           English             US  United States of America
# 2           English             US  United States of America
# 3           English             GB            United Kingdom
# 4           Deutsch             DE                   Germany
#
#   spoken_languages name  Profit%
# 0              Français   327.94
# 1               English   246.96
# 2               English   402.95
# 3               English   -93.35
# ...

# %%
# Abrar - 10/27/2020 add a column 'Profit'
profit_df = movie_temp_df['revenue'] - movie_temp_df['budget']
#print (profit_df)
movie_temp_df['Profit'] = profit_df 
movie_temp_df
movie_temp_df1 = movie_temp_df

# %%
# Split up our data into groups based upon 'genres' and summ the Profit column
revenue_grouped_by_Genres = movie_temp_df.groupby('genres')[['Profit']].sum()
print(revenue_grouped_by_Genres)
#revenue_grouped_by_Genres
# Out:
#                       Profit
# genres
#                    114160145
# Action           18745525868
# Adventure         3302020112
# Animation          548265148
# Comedy            2340540360
# Crime              241888535
# Documentary         12650197
# Drama             3924641888
# Family             479605706
# Fantasy            558213863
# History             66311483
# Horror             783105774
# Music               78897900
# Mystery            273237039
# Romance            120720286
# Science Fiction   1478935335
# TV Movie            37000000
# Thriller           514579476
# War                  3816240
# Western            -32849088

# %%
colors = ['red', 'green', 'blue', 'yellow', 'black', 'cyan']

fig, ax = plt.subplots()
ax.bar(revenue_grouped_by_Genres.index, revenue_grouped_by_Genres['Profit'],color = colors, edgecolor = 'green',width = 0.25)

plt.title('Genres vs Profit')
plt.xlabel('Genres')
plt.ylabel('Profit in Millions')
labels = ax.get_xticklabels()
plt.setp(labels, rotation = 45, horizontalalignment = 'right')
plt.ylim(500000, 19900000000)
plt.xlim(0,19) 
plt.subplots_adjust(bottom = 0.3, left = 0.1)
plt.figure( figsize=(10,10))

#plt.figure(figsize=(#,#))
#plt.figure(figsize=(100,100))

    
#matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)[source]

plt.show()

# %%
sns.set()


sales_data = movie_temp_df1.groupby('genres')[['budget', 'Profit']].sum()

index = np.arange(20)
bar_width = 0.2

r1 = plt1.bar(index, sales_data['budget'],
       bar_width, color = 'green', label = 'Budget')

r2 = plt1.bar(index + bar_width, sales_data['Profit'],
       bar_width, color = 'blue', label = 'Profit')

plt1.xticks(index + bar_width, sales_data.index,
      color = 'green',rotation = 45, horizontalalignment = 'right')

plt1.figure( figsize=(20,10))

plt1.legend()
plt1.tight_layout()
plt1.show()

# End -Stop  ABrar 10/26/2020 -
# Out:
# No handles with labels found to put in legend.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()


movie_grp_plt = movie_temp_df.groupby('genres')[['budget', 'Profit']].sum()

plt.bar(movie_grp_plt.index, movie_grp_plt['Profit'], color = 'rgbymck')

plt.xticks(color = 'green',rotation = 45, horizontalalignment = 'right')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5b7abff44946> in <module>
#       5
#       6
# ----> 7 movie_grp_plt = movie_temp_df.groupby('genres')[['budget', 'Profit']].sum()
#       8
#       9 plt.bar(movie_grp_plt.index, movie_grp_plt['Profit'], color = 'rgbymck')
#
# NameError: name 'movie_temp_df' is not defined
